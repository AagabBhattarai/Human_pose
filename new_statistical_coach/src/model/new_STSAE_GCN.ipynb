# %%
# import numpy as np
# import torch

# def k_adjacency(A, k, with_self=False, self_factor=1):
#     # A is a 2D square array
#     if isinstance(A, torch.Tensor):
#         A = A.data.cpu().numpy()
#     assert isinstance(A, np.ndarray)
#     Iden = np.eye(len(A), dtype=A.dtype)
#     if k == 0:
#         return Iden
#     Ak = np.minimum(np.linalg.matrix_power(A + Iden, k), 1) - np.minimum(np.linalg.matrix_power(A + Iden, k - 1), 1)
#     if with_self:
#         Ak += (self_factor * Iden)
#     return Ak

# def edge2mat(link, num_node):
#     A = np.zeros((num_node, num_node))
#     for i, j in link:
#         A[j, i] = 1
#     return A

# def normalize_digraph(A, dim=0):
#     # A is a 2D square array
#     Dl = np.sum(A, dim)
#     h, w = A.shape
#     Dn = np.zeros((w, w))

#     for i in range(w):
#         if Dl[i] > 0:
#             Dn[i, i] = Dl[i] ** (-1)

#     AD = np.dot(A, Dn)
#     return AD

# def get_hop_distance(num_node, edge, max_hop=1):
#     A = np.eye(num_node)

#     for i, j in edge:
#         A[i, j] = 1
#         A[j, i] = 1

#     # compute hop steps
#     hop_dis = np.zeros((num_node, num_node)) + np.inf
#     transfer_mat = [
#         np.linalg.matrix_power(A, d) for d in range(max_hop + 1)
#     ]
#     arrive_mat = (np.stack(transfer_mat) > 0)
#     for d in range(max_hop, -1, -1):
#         hop_dis[arrive_mat[d]] = d
#     return hop_dis

# class Graph:
#     """The Graph to model the skeletons.

#     Args:
#         layout (str): must be one of the following candidates: 'mediapipe'. Default: 'mediapipe'.
#         mode (str): must be one of the following candidates: 'stgcn_spatial', 'spatial'. Default: 'spatial'.
#         max_hop (int): the maximal distance between two connected nodes.
#             Default: 1
#     """

#     def __init__(self,
#                  layout='mediapipe',
#                  mode='spatial',
#                  max_hop=1,
#                  nx_node=1,
#                  num_filter=3,
#                  init_std=0.02,
#                  init_off=0.04):

#         self.max_hop = max_hop
#         self.layout = layout
#         self.mode = mode
#         self.num_filter = num_filter
#         self.init_std = init_std
#         self.init_off = init_off
#         self.nx_node = nx_node

#         assert nx_node == 1 or mode == 'random', "nx_node can be > 1 only if mode is 'random'"
#         assert layout in ['mediapipe']

#         self.get_layout(layout)
#         self.hop_dis = get_hop_distance(self.num_node, self.inward, max_hop)

#         assert hasattr(self, mode), f'Do Not Exist This Mode: {mode}'
#         self.A = getattr(self, mode)()

#     def __str__(self):
#         return self.A

#     def get_layout(self, layout):
#         if layout == 'mediapipe':
#             self.num_node = 33
#             # self.inward = [
#             #     (0, 1), (1, 2), (2, 3), (3, 7),  # Left arm
#             #     (0, 4), (4, 5), (5, 6), (6, 8),  # Right arm
#             #     (0, 9), (9, 10), (10, 11), (11, 23), (11, 24),  # Body
#             #     (12, 11), (12, 13), (13, 14), (14, 15), (14, 16),  # Left leg
#             #     (11, 23), (23, 24), (24, 25), (25, 26), (25, 27),  # Right leg
#             #     (15, 17), (15, 19), (16, 18), (16, 20),  # Left foot
#             #     (26, 28), (26, 30), (27, 29), (27, 31)  # Right foot
#             # ]

#             self.inward = [
#                 # Torso
#                 (12, 11), (24,12), (24, 23), (23, 11),  # shoulders to hips
#                 # Right arm
#                 (14, 12), (16, 14), (18,16), (20, 18), (20, 22),  # shoulder to fingertip
#                 # Left arm
#                 (13, 11), (15, 13), (17, 15), (19, 17), (21, 19),  # shoulder to fingertip
#                 # Right leg
#                 (26, 24), (28, 26), (30, 28), (32, 30),  # hip to foot
#                 # Left leg
#                 (25, 23), (27, 25), (29, 27), (31, 29),  # hip to foot
#                 # Face
#                 (1, 0), (2,1), (3, 2), (7, 3),  # right eye
#                 (4, 0), (5, 4), (6, 5), (8, 6),  # left eye
#                 (10, 9),  # mouth
#                 # Add connections to nose (0) from shoulders
#                 # (0, 11), (0, 12)  # do we include this connection dear friend?
#             ]
#             self.center = 11  # Left shoulder as the center
#         else:
#             raise ValueError(f'Do Not Exist This Layout: {layout}')
#         self.self_link = [(i, i) for i in range(self.num_node)]
#         self.outward = [(j, i) for (i, j) in self.inward]
#         self.neighbor = self.inward + self.outward

#     def stgcn_spatial(self):
#         adj = np.zeros((self.num_node, self.num_node))
#         adj[self.hop_dis <= self.max_hop] = 1
#         normalize_adj = normalize_digraph(adj)
#         hop_dis = self.hop_dis
#         center = self.center

#         A = []
#         for hop in range(self.max_hop + 1):
#             a_close = np.zeros((self.num_node, self.num_node))
#             a_further = np.zeros((self.num_node, self.num_node))
#             for i in range(self.num_node):
#                 for j in range(self.num_node):
#                     if hop_dis[j, i] == hop:
#                         if hop_dis[j, center] >= hop_dis[i, center]:
#                             a_close[j, i] = normalize_adj[j, i]
#                         else:
#                             a_further[j, i] = normalize_adj[j, i]
#             A.append(a_close)
#             if hop > 0:
#                 A.append(a_further)
#         return np.stack(A)

#     def spatial(self):
#         Iden = edge2mat(self.self_link, self.num_node)
#         In = normalize_digraph(edge2mat(self.inward, self.num_node))
#         Out = normalize_digraph(edge2mat(self.outward, self.num_node))
#         A = np.stack((Iden, In, Out))
#         return A

#     def binary_adj(self):
#         A = edge2mat(self.inward + self.outward, self.num_node)
#         return A[None]

#     def random(self):
#         num_node = self.num_node * self.nx_node
#         return np.random.randn(self.num_filter, num_node, num_node) * self.init_std + self.init_off

# %%
import numpy as np 

def edge2mat(link, num_node):
    A = np.zeros((num_node, num_node))
    for i, j in link:
        A[j, i] = 1
    return A

def normalize_digraph(A, dim=0):
    # A is a 2D square array
    Dl = np.sum(A, dim)
    h, w = A.shape
    Dn = np.zeros((w, w))

    for i in range(w):
        if Dl[i] > 0:
            Dn[i, i] = Dl[i] ** (-1)

    AD = np.dot(A, Dn)
    return AD

class Graph:
    """The Graph to model the skeletons.

    Args:
        layout (str): must be one of the following candidates: 'mediapipe'. Default: 'mediapipe'.
        mode (str): must be one of the following candidates: 'stgcn_spatial', 'spatial'. Default: 'spatial'.
        max_hop (int): the maximal distance between two connected nodes.
            Default: 1
    """

    def __init__(self,
                layout='mediapipe',
                mode='spatial',
                max_hop=1,
                nx_node=1,
                num_filter=3,
                init_std=0.02,
                init_off=0.04):

        self.max_hop = max_hop
        self.layout = layout
        self.mode = mode
        self.num_filter = num_filter
        self.init_std = init_std
        self.init_off = init_off
        self.nx_node = nx_node

        assert nx_node == 1 or mode == 'random', "nx_node can be > 1 only if mode is 'random'"
        assert layout in ['mediapipe']

        self.get_layout(layout)
       #  self.hop_dis = get_hop_distance(self.num_node, self.inward, max_hop)

        assert hasattr(self, mode), f'Do Not Exist This Mode: {mode}'
        self.A = getattr(self, mode)()

    def __str__(self):
        return self.A

    def get_layout(self, layout):
        if layout == 'mediapipe':
            self.num_node = 33
            self.inward = [
                # Torso
                (12, 11), (24, 12), (24, 23), (23, 11),  # shoulders to hips
                # Right arm
                (14, 12), (16, 14), (18, 16), (20, 18), (20, 22),  # shoulder to fingertip
                # Left arm
                (13, 11), (15, 13), (17, 15), (19, 17), (21, 19),  # shoulder to fingertip
                # Right leg
                (26, 24), (28, 26), (30, 28), (32, 30),  # hip to foot
                # Left leg
                (25, 23), (27, 25), (29, 27), (31, 29),  # hip to foot
                # Face
                (1, 0), (2, 1), (3, 2), (7, 3),  # right eye
                (4, 0), (5, 4), (6, 5), (8, 6),  # left eye
                (10, 9),  # mouth
                # Add connections to nose (0) from shoulders
                # (0, 11), (0, 12)  # do we include this connection dear friend?
            ]
            self.center = 11  # Left shoulder as the center
        else:
            raise ValueError(f'Do Not Exist This Layout: {layout}')
        self.self_link = [(i, i) for i in range(self.num_node)]
        self.outward = [(j, i) for (i, j) in self.inward]
        self.neighbor = self.inward + self.outward

    def spatial(self):
        Iden = edge2mat(self.self_link, self.num_node)
        In = normalize_digraph(edge2mat(self.inward, self.num_node))
        Out = normalize_digraph(edge2mat(self.outward, self.num_node))
        A = np.stack((Iden, In, Out))
        return A

# %%
graph = Graph()
A = graph.A

# %%
print(A.shape)  # Should be (3, 33, 33)

# Visualize connections with color explanations and larger size
import matplotlib.pyplot as plt

# Create a figure with 3 subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot identity matrix
im0 = axes[0].matshow(A[0], cmap='viridis')
axes[0].set_title('Identity Matrix\n(White=1, Black=0)')
fig.colorbar(im0, ax=axes[0], fraction=0.046, pad=0.04)

# Plot inward edges
im1 = axes[1].matshow(A[1], cmap='viridis')
axes[1].set_title('Inward Edges\n(White=1, Black=0)')
fig.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

# Plot outward edges
im2 = axes[2].matshow(A[2], cmap='viridis')
axes[2].set_title('Outward Edges\n(White=1, Black=0)')
fig.colorbar(im2, ax=axes[2], fraction=0.046, pad=0.04)

# Add node numbers
for ax in axes:
    ax.set_xticks(range(33))
    ax.set_yticks(range(33))
    ax.set_xticklabels(range(1, 34))
    ax.set_yticklabels(range(1, 34))
    ax.tick_params(axis='both', which='major', labelsize=8)

plt.tight_layout()
plt.show()
# Out:
# (3, 33, 33)

# %%
# Find and print indices where value == 0.5
for i in range(A.shape[1]):
    for j in range(A.shape[2]):
        if A[1, i, j] == 0.5 or A[2, i, j] == 0.5:
            print(f"({i}, {j}) has value 0.5")
# Out:
# (1, 0) has value 0.5
# (4, 0) has value 0.5
# (12, 24) has value 0.5
# (14, 12) has value 0.5
# (18, 20) has value 0.5
# (22, 20) has value 0.5
# (23, 24) has value 0.5
# (24, 12) has value 0.5
# (24, 23) has value 0.5
# (25, 23) has value 0.5

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class AGCN(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels,
                 adaptive='init',
                 conv_pos='pre',
                 with_res=False):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.graph = Graph()
        A = torch.tensor(self.graph.A, dtype=torch.float32, requires_grad=False)
        self.num_subsets = A.size(0)
        print("NUM_SUBSET:", self.num_subsets)
        self.adaptive = adaptive
        self.conv_pos = conv_pos
        self.with_res = with_res

        self.A = nn.Parameter(A.clone())

        if self.conv_pos == 'pre':
            self.conv = nn.Conv2d(in_channels, out_channels * self.num_subsets, 1)
        elif self.conv_pos == 'post':
            self.conv = nn.Conv2d(self.num_subsets * in_channels, out_channels, 1)

        if self.with_res:
            if in_channels != out_channels:
                self.residual = nn.Sequential(
                    nn.Conv2d(in_channels, out_channels, 1),
                    nn.BatchNorm2d(out_channels))
            else:
                self.residual = lambda x: x

        self.batch_norm = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        n, c, t, v = x.shape
        res = self.residual(x) if self.with_res else 0

        A = self.A

        if self.conv_pos == 'pre':
            x = self.conv(x)
            x = x.view(n, self.num_subsets, -1, t, v)
            x = torch.einsum('nkctv,kvw->nctw', (x, A)).contiguous()
        elif self.conv_pos == 'post':
            x = torch.einsum('nctv,kvw->nkctw', (x, A)).contiguous()
            x = x.view(n, -1, t, v)
            x = self.conv(x)

        return F.relu(self.batch_norm(x) + res)

    def init_weights(self):
        pass

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        if hasattr(m, 'weight'):
            nn.init.kaiming_normal_(m.weight, mode='fan_out')
        if hasattr(m, 'bias') and m.bias is not None and isinstance(m.bias, torch.Tensor):
            nn.init.constant_(m.bias, 0)
    elif classname.find('BatchNorm') != -1:
        if hasattr(m, 'weight') and m.weight is not None:
            m.weight.data.normal_(1.0, 0.02)
        if hasattr(m, 'bias') and m.bias is not None:
            m.bias.data.fill_(0)

# %%
class STSAM(nn.Module):
    def __init__(self, in_channels):
        super(STSAM, self).__init__()

        # 1x1 convolutions for Q, K, V
        self.query_conv = nn.Conv2d(in_channels, in_channels, kernel_size=1)
        self.key_conv = nn.Conv2d(in_channels, in_channels, kernel_size=1)
        self.value_conv = nn.Conv2d(in_channels, in_channels, kernel_size=1)

        # 1x1 convolutions for scaling attention maps
        self.Ws = nn.Conv2d(in_channels, 1, kernel_size=1)
        self.Wt = nn.Conv2d(in_channels, 1, kernel_size=1)

    def forward(self, x):
        N, C, T, V = x.size()

        # Generate Q, K, V
        Q = self.query_conv(x)
        K = self.key_conv(x)
        V = self.value_conv(x)

        # Spatial attention
        Qs = torch.mean(Q, dim=2, keepdim=True)  # (N, C, 1, V)
        Ks = torch.mean(K, dim=2, keepdim=True)  # (N, C, 1, V)
        Vs = torch.mean(V, dim=2, keepdim=True)  # (N, C, 1, V)

        # Temporal attention
        Qt = torch.mean(Q, dim=3, keepdim=True)  # (N, C, T, 1)
        Kt = torch.mean(K, dim=3, keepdim=True)  # (N, C, T, 1)
        Vt = torch.mean(V, dim=3, keepdim=True)  # (N, C, T, 1)

        # Compute attention maps
        Ms = torch.matmul(Qs.transpose(2, 3), Ks) / torch.sqrt(torch.tensor(C, dtype=torch.float))  # Spatial attention
        Ms = torch.softmax(Ms, dim=-1)
        Ms = torch.matmul(Ms, Vs.transpose(2, 3)).transpose(2, 3)

        Mt = torch.matmul(Qt.transpose(2, 3), Kt) / torch.sqrt(torch.tensor(C, dtype=torch.float))  # Temporal attention
        Mt = torch.softmax(Mt, dim=-1)
        Mt = torch.matmul(Mt, Vt.transpose(2, 3)).transpose(2, 3)

        # Scale attention maps
        Ms1 = torch.sigmoid(self.Ws(Ms))  # (N, 1, 1, V)
        Mt1 = torch.sigmoid(self.Wt(Mt))  # (N, 1, T, 1)

        # Apply attention with residual connections
        out = (x + x * Ms1) + ( x * Mt1)

        return out, Ms1, Mt1

# %%
class TemporalConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, dilation=1):
        super(TemporalConv, self).__init__()
        pad = (kernel_size + (kernel_size-1) * (dilation-1) - 1) // 2
        self.conv = nn.Conv2d(
            in_channels,
            out_channels,
            kernel_size=(kernel_size, 1),
            padding=(pad, 0),
            stride=(stride, 1),
            dilation=(dilation, 1))

        self.bn = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return x


class MTCN(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels,
                 kernel_size=3,
                 stride=1,
                 dilations=[1,2,3,4],
                 residual=True,
                 residual_kernel_size=1):

        super().__init__()
        assert out_channels % (len(dilations) + 2) == 0, '# out channels should be multiples of # branches'

        # Multiple branches of temporal convolution
        self.num_branches = len(dilations) + 2
        branch_channels = out_channels // self.num_branches
        if type(kernel_size) == list:
            assert len(kernel_size) == len(dilations)
        else:
            kernel_size = [kernel_size]*len(dilations)
        # Temporal Convolution branches
        self.branches = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(
                    in_channels,
                    branch_channels,
                    kernel_size=1,
                    padding=0),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU(inplace=True),
                TemporalConv(
                    branch_channels,
                    branch_channels,
                    kernel_size=ks,
                    stride=stride,
                    dilation=dilation),
            )
            for ks, dilation in zip(kernel_size, dilations)
        ])

        # Additional Max & 1x1 branch
        self.branches.append(nn.Sequential(
            nn.Conv2d(in_channels, branch_channels, kernel_size=1, padding=0),
            nn.BatchNorm2d(branch_channels),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=(3,1), stride=(stride,1), padding=(1,0)),
            nn.BatchNorm2d(branch_channels)
        ))

        self.branches.append(nn.Sequential(
            nn.Conv2d(in_channels, branch_channels, kernel_size=1, padding=0, stride=(stride,1)),
            nn.BatchNorm2d(branch_channels)
        ))

        # Residual connection
        if not residual:
            self.residual = lambda x: 0
        elif (in_channels == out_channels) and (stride == 1):
            self.residual = lambda x: x
        else:
            self.residual = TemporalConv(in_channels, out_channels, kernel_size=residual_kernel_size, stride=stride)

        # initialize
        self.apply(weights_init)

    def forward(self, x):
        # Input dim: (N,C,T,V)
        res = self.residual(x)
        branch_outs = []
        for tempconv in self.branches:
            out = tempconv(x)
            branch_outs.append(out)

        out = torch.cat(branch_outs, dim=1)
        out += res
        return out

# %%
class STSAE_GCN_Block(nn.Module):
    def __init__(self, in_channels, out_channels, residual= True, stride =1):
        super(STSAE_GCN_Block, self).__init__()
        self.agcn = AGCN(in_channels, out_channels)
        self.stsam = STSAM(out_channels)
        self.mtcn = MTCN(out_channels, out_channels)
        self.relu = nn.ReLU()
        if not residual:
            self.residual = lambda x: 0
        elif (in_channels == out_channels) and (stride == 1):
            self.residual = lambda x: x
        else:
            self.residual =TemporalConv(in_channels, out_channels, kernel_size=1, stride=stride)
    def forward(self, x):
        res = self.residual(x)
        x = self.agcn(x)
        x = self.stsam(x)
        x = self.mtcn(x) + res
        # x = x + res
        return self.relu(x)



class STSAE_GCN(nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes, num_frames, num_blocks=9):
        super(STSAE_GCN, self).__init__()
        self.num_blocks = num_blocks
        num_nodes = 33
        self.batch_norm = nn.BatchNorm1d(in_channels* num_nodes)
        self.blocks = nn.ModuleList([
            STSAE_GCN_Block(in_channels if i == 0 else hidden_channels,
                            hidden_channels, residual=False if i == 0 else True)
            for i in range(num_blocks)
        ])
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))  # Global Average Pooling
        self.fc = nn.Linear(hidden_channels, num_classes)  # Only hidden_channels remain after pooling

    def forward(self, x):
        # x shape: (batch_size, in_channels, num_frames, num_nodes)
        
        print("SHAPE X:", x.shape)
        N, C, T, V = x.size()
        x = x.permute(0,3,1,2).contiguous()
        x = x.view(N, V*C, T)
        x = self.batch_norm(x)
        x = x.view(N, V,C, T).permute(0,2,3,1)

        for block in self.blocks:
            x = block(x)
            print("X SHAPE:", x.shape)

        # Apply Global Average Pooling
        x = self.avg_pool(x).squeeze(-1).squeeze(-1)  # Reduce to (batch_size, hidden_channels)

        # Fully connected layer
        x = self.fc(x)
        return x

    def count_parameters(self):
        total_params = 0
        for name, parameter in self.named_parameters():
            if parameter.requires_grad:
                params = parameter.numel()
                print(f"{name}: {params}")
                total_params += params
        print(f"Total Trainable Params: {total_params}")

# %%
# Create dummy data
batch_size = 8
in_channels = 3  # x, y, confidence
num_frames = 30  # 1 second of video at 30 fps
num_nodes = 33  # BlazePose skeleton

# Generate random data in range [0, 1] for x, y coordinates and confidence
dummy_data = torch.rand(batch_size, in_channels, num_frames, num_nodes)

# Create model instance
model = STSAE_GCN(in_channels=in_channels, 
                 hidden_channels=66, 
                 num_classes=10, 
                 num_frames=num_frames,
                 num_blocks=9)

# Forward pass
output = model(dummy_data)
print(f"Input shape: {dummy_data.shape}")
print(f"Output shape: {output.shape}")
print(f"Sample output: {output[0]}")
model.count_parameters()
# Out:
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# SHAPE X: torch.Size([8, 3, 30, 33])
# X SHAPE: torch.Size([8, 66, 30, 33])
# X SHAPE: torch.Size([8, 66, 30, 33])
# X SHAPE: torch.Size([8, 66, 30, 33])
# X SHAPE: torch.Size([8, 66, 30, 33])
# X SHAPE: torch.Size([8, 66, 30, 33])
# X SHAPE: torch.Size([8, 66, 30, 33])
# X SHAPE: torch.Size([8, 66, 30, 33])
# X SHAPE: torch.Size([8, 66, 30, 33])
# X SHAPE: torch.Size([8, 66, 30, 33])
# Input shape: torch.Size([8, 3, 30, 33])
# Output shape: torch.Size([8, 10])
# Sample output: tensor([ 3.5380,  6.4972, -2.1972, -1.3653,  0.8686, -8.3762, -0.1578, -0.7016,
#          3.1765,  0.5615], grad_fn=<SelectBackward0>)
# batch_norm.weight: 99
# batch_norm.bias: 99
# blocks.0.agcn.A: 3267
# blocks.0.agcn.conv.weight: 594
# blocks.0.agcn.conv.bias: 198
# blocks.0.agcn.batch_norm.weight: 66
# blocks.0.agcn.batch_norm.bias: 66
# blocks.0.stsam.query_conv.weight: 4356
# blocks.0.stsam.query_conv.bias: 66
# blocks.0.stsam.key_conv.weight: 4356
# blocks.0.stsam.key_conv.bias: 66
# blocks.0.stsam.value_conv.weight: 4356
# blocks.0.stsam.value_conv.bias: 66
# blocks.0.stsam.Ws.weight: 66
# blocks.0.stsam.Ws.bias: 1
# blocks.0.stsam.Wt.weight: 66
# blocks.0.stsam.Wt.bias: 1
# blocks.0.mtcn.branches.0.0.weight: 726
# blocks.0.mtcn.branches.0.0.bias: 11
# blocks.0.mtcn.branches.0.1.weight: 11
# blocks.0.mtcn.branches.0.1.bias: 11
# blocks.0.mtcn.branches.0.3.conv.weight: 363
# blocks.0.mtcn.branches.0.3.conv.bias: 11
# blocks.0.mtcn.branches.0.3.bn.weight: 11
# blocks.0.mtcn.branches.0.3.bn.bias: 11
# blocks.0.mtcn.branches.1.0.weight: 726
# blocks.0.mtcn.branches.1.0.bias: 11
# blocks.0.mtcn.branches.1.1.weight: 11
# blocks.0.mtcn.branches.1.1.bias: 11
# blocks.0.mtcn.branches.1.3.conv.weight: 363
# blocks.0.mtcn.branches.1.3.conv.bias: 11
# blocks.0.mtcn.branches.1.3.bn.weight: 11
# blocks.0.mtcn.branches.1.3.bn.bias: 11
# blocks.0.mtcn.branches.2.0.weight: 726
# blocks.0.mtcn.branches.2.0.bias: 11
# blocks.0.mtcn.branches.2.1.weight: 11
# blocks.0.mtcn.branches.2.1.bias: 11
# blocks.0.mtcn.branches.2.3.conv.weight: 363
# blocks.0.mtcn.branches.2.3.conv.bias: 11
# blocks.0.mtcn.branches.2.3.bn.weight: 11
# blocks.0.mtcn.branches.2.3.bn.bias: 11
# blocks.0.mtcn.branches.3.0.weight: 726
# blocks.0.mtcn.branches.3.0.bias: 11
# blocks.0.mtcn.branches.3.1.weight: 11
# blocks.0.mtcn.branches.3.1.bias: 11
# blocks.0.mtcn.branches.3.3.conv.weight: 363
# blocks.0.mtcn.branches.3.3.conv.bias: 11
# blocks.0.mtcn.branches.3.3.bn.weight: 11
# blocks.0.mtcn.branches.3.3.bn.bias: 11
# blocks.0.mtcn.branches.4.0.weight: 726
# blocks.0.mtcn.branches.4.0.bias: 11
# blocks.0.mtcn.branches.4.1.weight: 11
# blocks.0.mtcn.branches.4.1.bias: 11
# blocks.0.mtcn.branches.4.4.weight: 11
# blocks.0.mtcn.branches.4.4.bias: 11
# blocks.0.mtcn.branches.5.0.weight: 726
# blocks.0.mtcn.branches.5.0.bias: 11
# blocks.0.mtcn.branches.5.1.weight: 11
# blocks.0.mtcn.branches.5.1.bias: 11
# blocks.1.agcn.A: 3267
# blocks.1.agcn.conv.weight: 13068
# blocks.1.agcn.conv.bias: 198
# blocks.1.agcn.batch_norm.weight: 66
# blocks.1.agcn.batch_norm.bias: 66
# blocks.1.stsam.query_conv.weight: 4356
# blocks.1.stsam.query_conv.bias: 66
# blocks.1.stsam.key_conv.weight: 4356
# blocks.1.stsam.key_conv.bias: 66
# blocks.1.stsam.value_conv.weight: 4356
# blocks.1.stsam.value_conv.bias: 66
# blocks.1.stsam.Ws.weight: 66
# blocks.1.stsam.Ws.bias: 1
# blocks.1.stsam.Wt.weight: 66
# blocks.1.stsam.Wt.bias: 1
# blocks.1.mtcn.branches.0.0.weight: 726
# blocks.1.mtcn.branches.0.0.bias: 11
# blocks.1.mtcn.branches.0.1.weight: 11
# blocks.1.mtcn.branches.0.1.bias: 11
# blocks.1.mtcn.branches.0.3.conv.weight: 363
# blocks.1.mtcn.branches.0.3.conv.bias: 11
# blocks.1.mtcn.branches.0.3.bn.weight: 11
# blocks.1.mtcn.branches.0.3.bn.bias: 11
# blocks.1.mtcn.branches.1.0.weight: 726
# blocks.1.mtcn.branches.1.0.bias: 11
# blocks.1.mtcn.branches.1.1.weight: 11
# blocks.1.mtcn.branches.1.1.bias: 11
# blocks.1.mtcn.branches.1.3.conv.weight: 363
# blocks.1.mtcn.branches.1.3.conv.bias: 11
# blocks.1.mtcn.branches.1.3.bn.weight: 11
# blocks.1.mtcn.branches.1.3.bn.bias: 11
# blocks.1.mtcn.branches.2.0.weight: 726
# blocks.1.mtcn.branches.2.0.bias: 11
# blocks.1.mtcn.branches.2.1.weight: 11
# blocks.1.mtcn.branches.2.1.bias: 11
# blocks.1.mtcn.branches.2.3.conv.weight: 363
# blocks.1.mtcn.branches.2.3.conv.bias: 11
# blocks.1.mtcn.branches.2.3.bn.weight: 11
# blocks.1.mtcn.branches.2.3.bn.bias: 11
# blocks.1.mtcn.branches.3.0.weight: 726
# blocks.1.mtcn.branches.3.0.bias: 11
# blocks.1.mtcn.branches.3.1.weight: 11
# blocks.1.mtcn.branches.3.1.bias: 11
# blocks.1.mtcn.branches.3.3.conv.weight: 363
# blocks.1.mtcn.branches.3.3.conv.bias: 11
# blocks.1.mtcn.branches.3.3.bn.weight: 11
# blocks.1.mtcn.branches.3.3.bn.bias: 11
# blocks.1.mtcn.branches.4.0.weight: 726
# blocks.1.mtcn.branches.4.0.bias: 11
# blocks.1.mtcn.branches.4.1.weight: 11
# blocks.1.mtcn.branches.4.1.bias: 11
# blocks.1.mtcn.branches.4.4.weight: 11
# blocks.1.mtcn.branches.4.4.bias: 11
# blocks.1.mtcn.branches.5.0.weight: 726
# blocks.1.mtcn.branches.5.0.bias: 11
# blocks.1.mtcn.branches.5.1.weight: 11
# blocks.1.mtcn.branches.5.1.bias: 11
# blocks.2.agcn.A: 3267
# blocks.2.agcn.conv.weight: 13068
# blocks.2.agcn.conv.bias: 198
# blocks.2.agcn.batch_norm.weight: 66
# blocks.2.agcn.batch_norm.bias: 66
# blocks.2.stsam.query_conv.weight: 4356
# blocks.2.stsam.query_conv.bias: 66
# blocks.2.stsam.key_conv.weight: 4356
# blocks.2.stsam.key_conv.bias: 66
# blocks.2.stsam.value_conv.weight: 4356
# blocks.2.stsam.value_conv.bias: 66
# blocks.2.stsam.Ws.weight: 66
# blocks.2.stsam.Ws.bias: 1
# blocks.2.stsam.Wt.weight: 66
# blocks.2.stsam.Wt.bias: 1
# blocks.2.mtcn.branches.0.0.weight: 726
# blocks.2.mtcn.branches.0.0.bias: 11
# blocks.2.mtcn.branches.0.1.weight: 11
# blocks.2.mtcn.branches.0.1.bias: 11
# blocks.2.mtcn.branches.0.3.conv.weight: 363
# blocks.2.mtcn.branches.0.3.conv.bias: 11
# blocks.2.mtcn.branches.0.3.bn.weight: 11
# blocks.2.mtcn.branches.0.3.bn.bias: 11
# blocks.2.mtcn.branches.1.0.weight: 726
# blocks.2.mtcn.branches.1.0.bias: 11
# blocks.2.mtcn.branches.1.1.weight: 11
# blocks.2.mtcn.branches.1.1.bias: 11
# blocks.2.mtcn.branches.1.3.conv.weight: 363
# blocks.2.mtcn.branches.1.3.conv.bias: 11
# blocks.2.mtcn.branches.1.3.bn.weight: 11
# blocks.2.mtcn.branches.1.3.bn.bias: 11
# blocks.2.mtcn.branches.2.0.weight: 726
# blocks.2.mtcn.branches.2.0.bias: 11
# blocks.2.mtcn.branches.2.1.weight: 11
# blocks.2.mtcn.branches.2.1.bias: 11
# blocks.2.mtcn.branches.2.3.conv.weight: 363
# blocks.2.mtcn.branches.2.3.conv.bias: 11
# blocks.2.mtcn.branches.2.3.bn.weight: 11
# blocks.2.mtcn.branches.2.3.bn.bias: 11
# blocks.2.mtcn.branches.3.0.weight: 726
# blocks.2.mtcn.branches.3.0.bias: 11
# blocks.2.mtcn.branches.3.1.weight: 11
# blocks.2.mtcn.branches.3.1.bias: 11
# blocks.2.mtcn.branches.3.3.conv.weight: 363
# blocks.2.mtcn.branches.3.3.conv.bias: 11
# blocks.2.mtcn.branches.3.3.bn.weight: 11
# blocks.2.mtcn.branches.3.3.bn.bias: 11
# blocks.2.mtcn.branches.4.0.weight: 726
# blocks.2.mtcn.branches.4.0.bias: 11
# blocks.2.mtcn.branches.4.1.weight: 11
# blocks.2.mtcn.branches.4.1.bias: 11
# blocks.2.mtcn.branches.4.4.weight: 11
# blocks.2.mtcn.branches.4.4.bias: 11
# blocks.2.mtcn.branches.5.0.weight: 726
# blocks.2.mtcn.branches.5.0.bias: 11
# blocks.2.mtcn.branches.5.1.weight: 11
# blocks.2.mtcn.branches.5.1.bias: 11
# blocks.3.agcn.A: 3267
# blocks.3.agcn.conv.weight: 13068
# blocks.3.agcn.conv.bias: 198
# blocks.3.agcn.batch_norm.weight: 66
# blocks.3.agcn.batch_norm.bias: 66
# blocks.3.stsam.query_conv.weight: 4356
# blocks.3.stsam.query_conv.bias: 66
# blocks.3.stsam.key_conv.weight: 4356
# blocks.3.stsam.key_conv.bias: 66
# blocks.3.stsam.value_conv.weight: 4356
# blocks.3.stsam.value_conv.bias: 66
# blocks.3.stsam.Ws.weight: 66
# blocks.3.stsam.Ws.bias: 1
# blocks.3.stsam.Wt.weight: 66
# blocks.3.stsam.Wt.bias: 1
# blocks.3.mtcn.branches.0.0.weight: 726
# blocks.3.mtcn.branches.0.0.bias: 11
# blocks.3.mtcn.branches.0.1.weight: 11
# blocks.3.mtcn.branches.0.1.bias: 11
# blocks.3.mtcn.branches.0.3.conv.weight: 363
# blocks.3.mtcn.branches.0.3.conv.bias: 11
# blocks.3.mtcn.branches.0.3.bn.weight: 11
# blocks.3.mtcn.branches.0.3.bn.bias: 11
# blocks.3.mtcn.branches.1.0.weight: 726
# blocks.3.mtcn.branches.1.0.bias: 11
# blocks.3.mtcn.branches.1.1.weight: 11
# blocks.3.mtcn.branches.1.1.bias: 11
# blocks.3.mtcn.branches.1.3.conv.weight: 363
# blocks.3.mtcn.branches.1.3.conv.bias: 11
# blocks.3.mtcn.branches.1.3.bn.weight: 11
# blocks.3.mtcn.branches.1.3.bn.bias: 11
# blocks.3.mtcn.branches.2.0.weight: 726
# blocks.3.mtcn.branches.2.0.bias: 11
# blocks.3.mtcn.branches.2.1.weight: 11
# blocks.3.mtcn.branches.2.1.bias: 11
# blocks.3.mtcn.branches.2.3.conv.weight: 363
# blocks.3.mtcn.branches.2.3.conv.bias: 11
# blocks.3.mtcn.branches.2.3.bn.weight: 11
# blocks.3.mtcn.branches.2.3.bn.bias: 11
# blocks.3.mtcn.branches.3.0.weight: 726
# blocks.3.mtcn.branches.3.0.bias: 11
# blocks.3.mtcn.branches.3.1.weight: 11
# blocks.3.mtcn.branches.3.1.bias: 11
# blocks.3.mtcn.branches.3.3.conv.weight: 363
# blocks.3.mtcn.branches.3.3.conv.bias: 11
# blocks.3.mtcn.branches.3.3.bn.weight: 11
# blocks.3.mtcn.branches.3.3.bn.bias: 11
# blocks.3.mtcn.branches.4.0.weight: 726
# blocks.3.mtcn.branches.4.0.bias: 11
# blocks.3.mtcn.branches.4.1.weight: 11
# blocks.3.mtcn.branches.4.1.bias: 11
# blocks.3.mtcn.branches.4.4.weight: 11
# blocks.3.mtcn.branches.4.4.bias: 11
# blocks.3.mtcn.branches.5.0.weight: 726
# blocks.3.mtcn.branches.5.0.bias: 11
# blocks.3.mtcn.branches.5.1.weight: 11
# blocks.3.mtcn.branches.5.1.bias: 11
# blocks.4.agcn.A: 3267
# blocks.4.agcn.conv.weight: 13068
# blocks.4.agcn.conv.bias: 198
# blocks.4.agcn.batch_norm.weight: 66
# blocks.4.agcn.batch_norm.bias: 66
# blocks.4.stsam.query_conv.weight: 4356
# blocks.4.stsam.query_conv.bias: 66
# blocks.4.stsam.key_conv.weight: 4356
# blocks.4.stsam.key_conv.bias: 66
# blocks.4.stsam.value_conv.weight: 4356
# blocks.4.stsam.value_conv.bias: 66
# blocks.4.stsam.Ws.weight: 66
# blocks.4.stsam.Ws.bias: 1
# blocks.4.stsam.Wt.weight: 66
# blocks.4.stsam.Wt.bias: 1
# blocks.4.mtcn.branches.0.0.weight: 726
# blocks.4.mtcn.branches.0.0.bias: 11
# blocks.4.mtcn.branches.0.1.weight: 11
# blocks.4.mtcn.branches.0.1.bias: 11
# blocks.4.mtcn.branches.0.3.conv.weight: 363
# blocks.4.mtcn.branches.0.3.conv.bias: 11
# blocks.4.mtcn.branches.0.3.bn.weight: 11
# blocks.4.mtcn.branches.0.3.bn.bias: 11
# blocks.4.mtcn.branches.1.0.weight: 726
# blocks.4.mtcn.branches.1.0.bias: 11
# blocks.4.mtcn.branches.1.1.weight: 11
# blocks.4.mtcn.branches.1.1.bias: 11
# blocks.4.mtcn.branches.1.3.conv.weight: 363
# blocks.4.mtcn.branches.1.3.conv.bias: 11
# blocks.4.mtcn.branches.1.3.bn.weight: 11
# blocks.4.mtcn.branches.1.3.bn.bias: 11
# blocks.4.mtcn.branches.2.0.weight: 726
# blocks.4.mtcn.branches.2.0.bias: 11
# blocks.4.mtcn.branches.2.1.weight: 11
# blocks.4.mtcn.branches.2.1.bias: 11
# blocks.4.mtcn.branches.2.3.conv.weight: 363
# blocks.4.mtcn.branches.2.3.conv.bias: 11
# blocks.4.mtcn.branches.2.3.bn.weight: 11
# blocks.4.mtcn.branches.2.3.bn.bias: 11
# blocks.4.mtcn.branches.3.0.weight: 726
# blocks.4.mtcn.branches.3.0.bias: 11
# blocks.4.mtcn.branches.3.1.weight: 11
# blocks.4.mtcn.branches.3.1.bias: 11
# blocks.4.mtcn.branches.3.3.conv.weight: 363
# blocks.4.mtcn.branches.3.3.conv.bias: 11
# blocks.4.mtcn.branches.3.3.bn.weight: 11
# blocks.4.mtcn.branches.3.3.bn.bias: 11
# blocks.4.mtcn.branches.4.0.weight: 726
# blocks.4.mtcn.branches.4.0.bias: 11
# blocks.4.mtcn.branches.4.1.weight: 11
# blocks.4.mtcn.branches.4.1.bias: 11
# blocks.4.mtcn.branches.4.4.weight: 11
# blocks.4.mtcn.branches.4.4.bias: 11
# blocks.4.mtcn.branches.5.0.weight: 726
# blocks.4.mtcn.branches.5.0.bias: 11
# blocks.4.mtcn.branches.5.1.weight: 11
# blocks.4.mtcn.branches.5.1.bias: 11
# blocks.5.agcn.A: 3267
# blocks.5.agcn.conv.weight: 13068
# blocks.5.agcn.conv.bias: 198
# blocks.5.agcn.batch_norm.weight: 66
# blocks.5.agcn.batch_norm.bias: 66
# blocks.5.stsam.query_conv.weight: 4356
# blocks.5.stsam.query_conv.bias: 66
# blocks.5.stsam.key_conv.weight: 4356
# blocks.5.stsam.key_conv.bias: 66
# blocks.5.stsam.value_conv.weight: 4356
# blocks.5.stsam.value_conv.bias: 66
# blocks.5.stsam.Ws.weight: 66
# blocks.5.stsam.Ws.bias: 1
# blocks.5.stsam.Wt.weight: 66
# blocks.5.stsam.Wt.bias: 1
# blocks.5.mtcn.branches.0.0.weight: 726
# blocks.5.mtcn.branches.0.0.bias: 11
# blocks.5.mtcn.branches.0.1.weight: 11
# blocks.5.mtcn.branches.0.1.bias: 11
# blocks.5.mtcn.branches.0.3.conv.weight: 363
# blocks.5.mtcn.branches.0.3.conv.bias: 11
# blocks.5.mtcn.branches.0.3.bn.weight: 11
# blocks.5.mtcn.branches.0.3.bn.bias: 11
# blocks.5.mtcn.branches.1.0.weight: 726
# blocks.5.mtcn.branches.1.0.bias: 11
# blocks.5.mtcn.branches.1.1.weight: 11
# blocks.5.mtcn.branches.1.1.bias: 11
# blocks.5.mtcn.branches.1.3.conv.weight: 363
# blocks.5.mtcn.branches.1.3.conv.bias: 11
# blocks.5.mtcn.branches.1.3.bn.weight: 11
# blocks.5.mtcn.branches.1.3.bn.bias: 11
# blocks.5.mtcn.branches.2.0.weight: 726
# blocks.5.mtcn.branches.2.0.bias: 11
# blocks.5.mtcn.branches.2.1.weight: 11
# blocks.5.mtcn.branches.2.1.bias: 11
# blocks.5.mtcn.branches.2.3.conv.weight: 363
# blocks.5.mtcn.branches.2.3.conv.bias: 11
# blocks.5.mtcn.branches.2.3.bn.weight: 11
# blocks.5.mtcn.branches.2.3.bn.bias: 11
# blocks.5.mtcn.branches.3.0.weight: 726
# blocks.5.mtcn.branches.3.0.bias: 11
# blocks.5.mtcn.branches.3.1.weight: 11
# blocks.5.mtcn.branches.3.1.bias: 11
# blocks.5.mtcn.branches.3.3.conv.weight: 363
# blocks.5.mtcn.branches.3.3.conv.bias: 11
# blocks.5.mtcn.branches.3.3.bn.weight: 11
# blocks.5.mtcn.branches.3.3.bn.bias: 11
# blocks.5.mtcn.branches.4.0.weight: 726
# blocks.5.mtcn.branches.4.0.bias: 11
# blocks.5.mtcn.branches.4.1.weight: 11
# blocks.5.mtcn.branches.4.1.bias: 11
# blocks.5.mtcn.branches.4.4.weight: 11
# blocks.5.mtcn.branches.4.4.bias: 11
# blocks.5.mtcn.branches.5.0.weight: 726
# blocks.5.mtcn.branches.5.0.bias: 11
# blocks.5.mtcn.branches.5.1.weight: 11
# blocks.5.mtcn.branches.5.1.bias: 11
# blocks.6.agcn.A: 3267
# blocks.6.agcn.conv.weight: 13068
# blocks.6.agcn.conv.bias: 198
# blocks.6.agcn.batch_norm.weight: 66
# blocks.6.agcn.batch_norm.bias: 66
# blocks.6.stsam.query_conv.weight: 4356
# blocks.6.stsam.query_conv.bias: 66
# blocks.6.stsam.key_conv.weight: 4356
# blocks.6.stsam.key_conv.bias: 66
# blocks.6.stsam.value_conv.weight: 4356
# blocks.6.stsam.value_conv.bias: 66
# blocks.6.stsam.Ws.weight: 66
# blocks.6.stsam.Ws.bias: 1
# blocks.6.stsam.Wt.weight: 66
# blocks.6.stsam.Wt.bias: 1
# blocks.6.mtcn.branches.0.0.weight: 726
# blocks.6.mtcn.branches.0.0.bias: 11
# blocks.6.mtcn.branches.0.1.weight: 11
# blocks.6.mtcn.branches.0.1.bias: 11
# blocks.6.mtcn.branches.0.3.conv.weight: 363
# blocks.6.mtcn.branches.0.3.conv.bias: 11
# blocks.6.mtcn.branches.0.3.bn.weight: 11
# blocks.6.mtcn.branches.0.3.bn.bias: 11
# blocks.6.mtcn.branches.1.0.weight: 726
# blocks.6.mtcn.branches.1.0.bias: 11
# blocks.6.mtcn.branches.1.1.weight: 11
# blocks.6.mtcn.branches.1.1.bias: 11
# blocks.6.mtcn.branches.1.3.conv.weight: 363
# blocks.6.mtcn.branches.1.3.conv.bias: 11
# blocks.6.mtcn.branches.1.3.bn.weight: 11
# blocks.6.mtcn.branches.1.3.bn.bias: 11
# blocks.6.mtcn.branches.2.0.weight: 726
# blocks.6.mtcn.branches.2.0.bias: 11
# blocks.6.mtcn.branches.2.1.weight: 11
# blocks.6.mtcn.branches.2.1.bias: 11
# blocks.6.mtcn.branches.2.3.conv.weight: 363
# blocks.6.mtcn.branches.2.3.conv.bias: 11
# blocks.6.mtcn.branches.2.3.bn.weight: 11
# blocks.6.mtcn.branches.2.3.bn.bias: 11
# blocks.6.mtcn.branches.3.0.weight: 726
# blocks.6.mtcn.branches.3.0.bias: 11
# blocks.6.mtcn.branches.3.1.weight: 11
# blocks.6.mtcn.branches.3.1.bias: 11
# blocks.6.mtcn.branches.3.3.conv.weight: 363
# blocks.6.mtcn.branches.3.3.conv.bias: 11
# blocks.6.mtcn.branches.3.3.bn.weight: 11
# blocks.6.mtcn.branches.3.3.bn.bias: 11
# blocks.6.mtcn.branches.4.0.weight: 726
# blocks.6.mtcn.branches.4.0.bias: 11
# blocks.6.mtcn.branches.4.1.weight: 11
# blocks.6.mtcn.branches.4.1.bias: 11
# blocks.6.mtcn.branches.4.4.weight: 11
# blocks.6.mtcn.branches.4.4.bias: 11
# blocks.6.mtcn.branches.5.0.weight: 726
# blocks.6.mtcn.branches.5.0.bias: 11
# blocks.6.mtcn.branches.5.1.weight: 11
# blocks.6.mtcn.branches.5.1.bias: 11
# blocks.7.agcn.A: 3267
# blocks.7.agcn.conv.weight: 13068
# blocks.7.agcn.conv.bias: 198
# blocks.7.agcn.batch_norm.weight: 66
# blocks.7.agcn.batch_norm.bias: 66
# blocks.7.stsam.query_conv.weight: 4356
# blocks.7.stsam.query_conv.bias: 66
# blocks.7.stsam.key_conv.weight: 4356
# blocks.7.stsam.key_conv.bias: 66
# blocks.7.stsam.value_conv.weight: 4356
# blocks.7.stsam.value_conv.bias: 66
# blocks.7.stsam.Ws.weight: 66
# blocks.7.stsam.Ws.bias: 1
# blocks.7.stsam.Wt.weight: 66
# blocks.7.stsam.Wt.bias: 1
# blocks.7.mtcn.branches.0.0.weight: 726
# blocks.7.mtcn.branches.0.0.bias: 11
# blocks.7.mtcn.branches.0.1.weight: 11
# blocks.7.mtcn.branches.0.1.bias: 11
# blocks.7.mtcn.branches.0.3.conv.weight: 363
# blocks.7.mtcn.branches.0.3.conv.bias: 11
# blocks.7.mtcn.branches.0.3.bn.weight: 11
# blocks.7.mtcn.branches.0.3.bn.bias: 11
# blocks.7.mtcn.branches.1.0.weight: 726
# blocks.7.mtcn.branches.1.0.bias: 11
# blocks.7.mtcn.branches.1.1.weight: 11
# blocks.7.mtcn.branches.1.1.bias: 11
# blocks.7.mtcn.branches.1.3.conv.weight: 363
# blocks.7.mtcn.branches.1.3.conv.bias: 11
# blocks.7.mtcn.branches.1.3.bn.weight: 11
# blocks.7.mtcn.branches.1.3.bn.bias: 11
# blocks.7.mtcn.branches.2.0.weight: 726
# blocks.7.mtcn.branches.2.0.bias: 11
# blocks.7.mtcn.branches.2.1.weight: 11
# blocks.7.mtcn.branches.2.1.bias: 11
# blocks.7.mtcn.branches.2.3.conv.weight: 363
# blocks.7.mtcn.branches.2.3.conv.bias: 11
# blocks.7.mtcn.branches.2.3.bn.weight: 11
# blocks.7.mtcn.branches.2.3.bn.bias: 11
# blocks.7.mtcn.branches.3.0.weight: 726
# blocks.7.mtcn.branches.3.0.bias: 11
# blocks.7.mtcn.branches.3.1.weight: 11
# blocks.7.mtcn.branches.3.1.bias: 11
# blocks.7.mtcn.branches.3.3.conv.weight: 363
# blocks.7.mtcn.branches.3.3.conv.bias: 11
# blocks.7.mtcn.branches.3.3.bn.weight: 11
# blocks.7.mtcn.branches.3.3.bn.bias: 11
# blocks.7.mtcn.branches.4.0.weight: 726
# blocks.7.mtcn.branches.4.0.bias: 11
# blocks.7.mtcn.branches.4.1.weight: 11
# blocks.7.mtcn.branches.4.1.bias: 11
# blocks.7.mtcn.branches.4.4.weight: 11
# blocks.7.mtcn.branches.4.4.bias: 11
# blocks.7.mtcn.branches.5.0.weight: 726
# blocks.7.mtcn.branches.5.0.bias: 11
# blocks.7.mtcn.branches.5.1.weight: 11
# blocks.7.mtcn.branches.5.1.bias: 11
# blocks.8.agcn.A: 3267
# blocks.8.agcn.conv.weight: 13068
# blocks.8.agcn.conv.bias: 198
# blocks.8.agcn.batch_norm.weight: 66
# blocks.8.agcn.batch_norm.bias: 66
# blocks.8.stsam.query_conv.weight: 4356
# blocks.8.stsam.query_conv.bias: 66
# blocks.8.stsam.key_conv.weight: 4356
# blocks.8.stsam.key_conv.bias: 66
# blocks.8.stsam.value_conv.weight: 4356
# blocks.8.stsam.value_conv.bias: 66
# blocks.8.stsam.Ws.weight: 66
# blocks.8.stsam.Ws.bias: 1
# blocks.8.stsam.Wt.weight: 66
# blocks.8.stsam.Wt.bias: 1
# blocks.8.mtcn.branches.0.0.weight: 726
# blocks.8.mtcn.branches.0.0.bias: 11
# blocks.8.mtcn.branches.0.1.weight: 11
# blocks.8.mtcn.branches.0.1.bias: 11
# blocks.8.mtcn.branches.0.3.conv.weight: 363
# blocks.8.mtcn.branches.0.3.conv.bias: 11
# blocks.8.mtcn.branches.0.3.bn.weight: 11
# blocks.8.mtcn.branches.0.3.bn.bias: 11
# blocks.8.mtcn.branches.1.0.weight: 726
# blocks.8.mtcn.branches.1.0.bias: 11
# blocks.8.mtcn.branches.1.1.weight: 11
# blocks.8.mtcn.branches.1.1.bias: 11
# blocks.8.mtcn.branches.1.3.conv.weight: 363
# blocks.8.mtcn.branches.1.3.conv.bias: 11
# blocks.8.mtcn.branches.1.3.bn.weight: 11
# blocks.8.mtcn.branches.1.3.bn.bias: 11
# blocks.8.mtcn.branches.2.0.weight: 726
# blocks.8.mtcn.branches.2.0.bias: 11
# blocks.8.mtcn.branches.2.1.weight: 11
# blocks.8.mtcn.branches.2.1.bias: 11
# blocks.8.mtcn.branches.2.3.conv.weight: 363
# blocks.8.mtcn.branches.2.3.conv.bias: 11
# blocks.8.mtcn.branches.2.3.bn.weight: 11
# blocks.8.mtcn.branches.2.3.bn.bias: 11
# blocks.8.mtcn.branches.3.0.weight: 726
# blocks.8.mtcn.branches.3.0.bias: 11
# blocks.8.mtcn.branches.3.1.weight: 11
# blocks.8.mtcn.branches.3.1.bias: 11
# blocks.8.mtcn.branches.3.3.conv.weight: 363
# blocks.8.mtcn.branches.3.3.conv.bias: 11
# blocks.8.mtcn.branches.3.3.bn.weight: 11
# blocks.8.mtcn.branches.3.3.bn.bias: 11
# blocks.8.mtcn.branches.4.0.weight: 726
# blocks.8.mtcn.branches.4.0.bias: 11
# blocks.8.mtcn.branches.4.1.weight: 11
# blocks.8.mtcn.branches.4.1.bias: 11
# blocks.8.mtcn.branches.4.4.weight: 11
# blocks.8.mtcn.branches.4.4.bias: 11
# blocks.8.mtcn.branches.5.0.weight: 726
# blocks.8.mtcn.branches.5.0.bias: 11
# blocks.8.mtcn.branches.5.1.weight: 11
# blocks.8.mtcn.branches.5.1.bias: 11
# fc.weight: 660
# fc.bias: 10
# Total Trainable Params: 314419

# %%
# class STSAE_GCN(nn.Module):
#     def __init__(self, in_channels, hidden_channels, num_classes, num_frames, num_blocks=9):
#         super(STSAE_GCN, self).__init__()
#         self.num_blocks = num_blocks

#         self.blocks = nn.ModuleList([
#             STSAE_GCN_Block(in_channels if i == 0 else hidden_channels,
#                             hidden_channels, residual=False if i == 0 else True)
#             for i in range(num_blocks)
#         ])
#         num_nodes = 33
#         self.fc = nn.Linear(hidden_channels * num_nodes * num_frames, num_classes)

#     def forward(self, x):
#         # x shape: (batch_size, in_channels, num_frames, num_nodes)
#         for block in self.blocks:
#             x = block(x)

#         # Global average pooling
#         x = x.view(x.size(0), -1)
#         x = self.fc(x)
#         return x

# %%
def load_checkpoint(model, optimizer, checkpoint_path):
    """
    Load model and training state from a checkpoint
    """
    print(f"Loading checkpoint from {checkpoint_path}")
    checkpoint = torch.load(checkpoint_path, weights_only = False,map_location='cpu')

    # Load model and optimizer states
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    # Get the epoch number to resume from
    start_epoch = checkpoint['epoch']

    # Load training history with new metrics
    history = checkpoint.get('history', {
        'train_loss': [], 'val_loss': [],
        'train_acc': [], 'val_acc': [],
        'train_precision': [], 'train_recall': [], 'train_f1': [],
        'val_precision': [], 'val_recall': [], 'val_f1': [],
        'learning_rates': []
    })

    return model, optimizer, start_epoch, history

# %%
# dataset = Yoga3DDataset(read_meta_data())
# label_to_pose = {v:k for k,v in dataset.pose_to_label.items()}
HIDDEN_CHANNELS = 120
NUM_CLASSES = 13
NUM_BLOCKS = 7
model = STSAE_GCN(3, HIDDEN_CHANNELS, NUM_CLASSES, 20,num_blocks=NUM_BLOCKS)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

import os
SAVE_PATH = './'
checkpoint_path = os.path.join(SAVE_PATH, 'best_model.pth')
# Plot the training curves
if checkpoint_path and os.path.exists(checkpoint_path):
        model, optimizer, start_epoch, history = load_checkpoint(
            model, optimizer, checkpoint_path
        )
        print(f"Resuming training from epoch {start_epoch}")
# plot_training_curves(history)
# Out:
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# NUM_SUBSET: 3
# Loading checkpoint from ./best_model.pth
# Resuming training from epoch 26

# %%
model
# Out:
# STSAE_GCN(
#   (batch_norm): BatchNorm1d(99, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (blocks): ModuleList(
#     (0): STSAE_GCN_Block(
#       (agcn): AGCN(
#         (conv): Conv2d(3, 360, kernel_size=(1, 1), stride=(1, 1))
#         (batch_norm): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stsam): STSAM(
#         (query_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (key_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (value_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (Ws): Conv2d(120, 1, kernel_size=(1, 1), stride=(1, 1))
#         (Wt): Conv2d(120, 1, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mtcn): MTCN(
#         (branches): ModuleList(
#           (0): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(2, 0), dilation=(2, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (2): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(3, 0), dilation=(3, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (3): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(4, 0), dilation=(4, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (4): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): MaxPool2d(kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), dilation=1, ceil_mode=False)
#             (4): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (5): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (relu): ReLU()
#     )
#     (1-6): 6 x STSAE_GCN_Block(
#       (agcn): AGCN(
#         (conv): Conv2d(120, 360, kernel_size=(1, 1), stride=(1, 1))
#         (batch_norm): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stsam): STSAM(
#         (query_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (key_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (value_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (Ws): Conv2d(120, 1, kernel_size=(1, 1), stride=(1, 1))
#         (Wt): Conv2d(120, 1, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mtcn): MTCN(
#         (branches): ModuleList(
#           (0): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(2, 0), dilation=(2, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (2): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(3, 0), dilation=(3, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (3): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(4, 0), dilation=(4, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (4): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): MaxPool2d(kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), dilation=1, ceil_mode=False)
#             (4): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (5): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (relu): ReLU()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=120, out_features=13, bias=True)
# )

# %%
def get_agcn_adjacency_matrices(model):
    adjacency_matrices = []
    for name, module in model.named_modules():
        if isinstance(module, AGCN):
            # Shape: (num_subsets, num_nodes, num_nodes)
            A = module.A.detach().cpu().numpy()
            adjacency_matrices.append((name, A))
    return adjacency_matrices

# %%
model.eval()
# Out:
# STSAE_GCN(
#   (batch_norm): BatchNorm1d(99, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (blocks): ModuleList(
#     (0): STSAE_GCN_Block(
#       (agcn): AGCN(
#         (conv): Conv2d(3, 360, kernel_size=(1, 1), stride=(1, 1))
#         (batch_norm): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stsam): STSAM(
#         (query_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (key_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (value_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (Ws): Conv2d(120, 1, kernel_size=(1, 1), stride=(1, 1))
#         (Wt): Conv2d(120, 1, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mtcn): MTCN(
#         (branches): ModuleList(
#           (0): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(2, 0), dilation=(2, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (2): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(3, 0), dilation=(3, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (3): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(4, 0), dilation=(4, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (4): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): MaxPool2d(kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), dilation=1, ceil_mode=False)
#             (4): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (5): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (relu): ReLU()
#     )
#     (1-6): 6 x STSAE_GCN_Block(
#       (agcn): AGCN(
#         (conv): Conv2d(120, 360, kernel_size=(1, 1), stride=(1, 1))
#         (batch_norm): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (stsam): STSAM(
#         (query_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (key_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (value_conv): Conv2d(120, 120, kernel_size=(1, 1), stride=(1, 1))
#         (Ws): Conv2d(120, 1, kernel_size=(1, 1), stride=(1, 1))
#         (Wt): Conv2d(120, 1, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mtcn): MTCN(
#         (branches): ModuleList(
#           (0): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(2, 0), dilation=(2, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (2): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(3, 0), dilation=(3, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (3): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): TemporalConv(
#               (conv): Conv2d(20, 20, kernel_size=(3, 1), stride=(1, 1), padding=(4, 0), dilation=(4, 1))
#               (bn): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (4): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): MaxPool2d(kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), dilation=1, ceil_mode=False)
#             (4): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (5): Sequential(
#             (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1))
#             (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (relu): ReLU()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=120, out_features=13, bias=True)
# )

# %%
all_A = get_agcn_adjacency_matrices(model)

# %%
all_A
# Select specific layers
first_layer_adj = all_A[0][1]  # (num_subsets, 33, 33)
middle_layer_adj = all_A[3][1]
last_layer_adj = all_A[6][1]
print(all_A[0][1].shape)
# Out:
# (3, 33, 33)

# %%
import matplotlib.pyplot as plt

def plot_adjacency_matrix(A, layer_name):
    """Plot first three subsets of the adjacency matrix in subplots"""
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    
    # Define subset names based on their index
    subset_names = {0: "Self Loop", 1: "Inward", 2: "Outward"}
    
    for i, ax in enumerate(axes):
        im = ax.imshow(A[i], cmap='viridis', interpolation='nearest')
        ax.set_title(f"Adjacency Matrix - {layer_name}\n{subset_names[i]}")
        ax.set_xlabel("Target Node")
        ax.set_ylabel("Source Node")
        fig.colorbar(im, ax=ax)
    
    plt.tight_layout()
    plt.show()

# Plot adjacency matrices for all blocks from 0 to 6
for idx, (name, A) in enumerate(all_A):
    if idx <= 6:  # Only plot up to block 6
        plot_adjacency_matrix(A, f"Block {idx}")
